# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilosauro/Arkham_Project/blob/master/Audio_Signal_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_path = "/content/Knife.mp3"
y, sr = librosa.load(audio_path)

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.title('Knife')
plt.xlabel('Tempo (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)

# Exiba o espectrograma
plt.figure(figsize=(10, 5))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma')
plt.show()
# Out:
# <ipython-input-10-de6e2c6a8468>:1: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
